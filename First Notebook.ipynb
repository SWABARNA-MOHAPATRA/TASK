# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Error! Division by zero."
    return x / y

def main():
    print("Basic Calculator")
    print("Select operation:")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")

    while True:
        choice = input("Enter choice (1/2/3/4): ")

        if choice in ['1', '2', '3', '4']:
            try:
                num1 = float(input("Enter first number: "))
                num2 = float(input("Enter second number: "))
            except ValueError:
                print("Invalid input. Please enter numeric values.")
                continue

            if choice == '1':
                print(f"{num1} + {num2} = {add(num1, num2)}")

            elif choice == '2':
                print(f"{num1} - {num2} = {subtract(num1, num2)}")

            elif choice == '3':
                print(f"{num1} * {num2} = {multiply(num1, num2)}")

            elif choice == '4':
                result = divide(num1, num2)
                if result == "Error! Division by zero.":
                    print(result)
                else:
                    print(f"{num1} / {num2} = {result}")

        else:
            print("Invalid choice. Please choose a valid operation.")

        next_calculation = input("Do you want to perform another calculation? (yes/no): ")
        if next_calculation.lower() != 'yes':
            print("Exiting the calculator. Goodbye!")
            break

if __name__ == "__main__":
    main()
# Out:
# Basic Calculator
# Select operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter choice (1/2/3/4): 1
# Enter first number: 10
# Enter second number: 5
# 10.0 + 5.0 = 15.0
# Do you want to perform another calculation? (yes/no): YES
# Enter choice (1/2/3/4): 2
# Enter first number: 10
# Enter second number: 5
# 10.0 - 5.0 = 5.0
# Do you want to perform another calculation? (yes/no): YES
# Enter choice (1/2/3/4): 3
# Enter first number: 10
# Enter second number: 5
# 10.0 * 5.0 = 50.0
# Do you want to perform another calculation? (yes/no): YES
# Enter choice (1/2/3/4): 4
# Enter first number: 10
# Enter second number: 5
# 10.0 / 5.0 = 2.0
# Do you want to perform another calculation? (yes/no): YES
# Enter choice (1/2/3/4): 4
# Enter first number: 10
# Enter second number: 0
# Error! Division by zero.
# Do you want to perform another calculation? (yes/no): NO
# Exiting the calculator. Goodbye!

# %%
# Define the main data structure to hold student grades
students = {}

# Function to add a new student
def add_student(student_id, student_name):
    if student_id in students:
        print(f"Student ID {student_id} already exists.")
    else:
        students[student_id] = {"name": student_name, "grades": []}
        print(f"Student {student_name} added with ID {student_id}.")

# Function to add a grade for a student
def add_grade(student_id, grade):
    if student_id not in students:
        print(f"Student ID {student_id} does not exist.")
    else:
        students[student_id]["grades"].append(grade)
        print(f"Grade {grade} added for student ID {student_id}.")

# Function to get the grades of a student
def get_grades(student_id):
    if student_id not in students:
        print(f"Student ID {student_id} does not exist.")
    else:
        return students[student_id]["grades"]

# Function to calculate the average grade of a student
def calculate_average(student_id):
    if student_id not in students:
        print(f"Student ID {student_id} does not exist.")
    else:
        grades = students[student_id]["grades"]
        if not grades:
            print("No grades available for this student.")
            return None
        return sum(grades) / len(grades)

# Command-line interface
def main():
    while True:
        print("\nStudent Grade Management System")
        print("1. Add a student")
        print("2. Add a grade for a student")
        print("3. Get grades for a student")
        print("4. Calculate average grade for a student")
        print("5. Exit")
        choice = input("Enter your choice: ")

        if choice == '1':
            student_id = input("Enter student ID: ")
            student_name = input("Enter student name: ")
            add_student(student_id, student_name)
        elif choice == '2':
            student_id = input("Enter student ID: ")
            try:
                grade = float(input("Enter grade: "))
                add_grade(student_id, grade)
            except ValueError:
                print("Invalid grade. Please enter a number.")
        elif choice == '3':
            student_id = input("Enter student ID: ")
            grades = get_grades(student_id)
            if grades is not None:
                print(f"Grades for student ID {student_id}: {grades}")
        elif choice == '4':
            student_id = input("Enter student ID: ")
            average = calculate_average(student_id)
            if average is not None:
                print(f"Average grade for student ID {student_id}: {average:.2f}")
        elif choice == '5':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 1
# Enter student ID: 001
# Enter student name: SWABARNA
# Student SWABARNA added with ID 001.
#
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 1
# Enter student ID: 002
# Enter student name: KHUSI
# Student KHUSI added with ID 002.
#
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 2
# Enter student ID: 001
# Enter grade: 85
# Grade 85.0 added for student ID 001.
#
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 2
# Enter student ID: 001
# Enter grade: 92
# Grade 92.0 added for student ID 001.
#
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 2
# Enter student ID: 002
# Enter grade: 78
# Grade 78.0 added for student ID 002.
#
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 3
# Enter student ID: 001
# Grades for student ID 001: [85.0, 92.0]
#
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 4
# Enter student ID: 001
# Average grade for student ID 001: 88.50
#
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 4
# Enter student ID: 002
# Average grade for student ID 002: 78.00
#
# Student Grade Management System
# 1. Add a student
# 2. Add a grade for a student
# 3. Get grades for a student
# 4. Calculate average grade for a student
# 5. Exit
# Enter your choice: 5
# Exiting the program.
